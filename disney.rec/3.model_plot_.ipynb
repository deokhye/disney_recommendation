# %%
import pandas as pd
import numpy as np
from ast import literal_eval

# %%
from codetotitle import CodetoTitle

# %%
movies = pd.read_csv('final_plot.csv', encoding='utf-8', names=['code', 'plot'])
movies = movies.loc[:, ['code','plot']]

# %%
tfidf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ea18ce4de16c> in <module>
# ----> 1 tfidf
#
# NameError: name 'tfidf' is not defined

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# ngram_range=(1, 2) 는 단어를 1개 혹은 2개 연속으로 보겠다
tfidf_vec = TfidfVectorizer(ngram_range=(1, 2))
tfidf_matrix = tfidf_vec.fit_transform(movies['plot'])
print(tfidf_vec.vocabulary_.items())
print(tfidf_matrix.shape)
# Out:
# , 21436), ('얘기하는', 67706), ('콜튼', 103093), ('천국에서의', 98184), ('상세하게', 51386), ('털어놓는', 104800), ('콜튼의', 103099), ('들썩이기', 28082), ('소동에', 55762), ('조용했던', 92752), ('천국을', 98190), ('콜튼으로', 103095), ('토드와', 105076), ('천국은', 98188), ('진짜였을까', 96178), ('조용한 시골', 92750), ('시골 마을의', 60536), ('마을의 토드는', 33460), ('토드는 마을', 105075), ('마을 주민들을', 33425), ('주민들을 도우며', 93694), ('도우며 성실하게', 25602), ('성실하게 살고', 54183), ('있는 가정의', 84503), ('가정의 가장이다', 4019), ('가장이다 그러던', 4005), ('어느 그의', 67724), ('그의 네살배기', 14943), ('네살배기 아들', 19624), ('아들 콜튼이', 63891), ('콜튼이 위급한', 103103), ('위급한 상태에', 77704), ('상태에 빠지게', 51576), ('빠지게 되고', 49084), ('되고 결국', 26768), ('결국 손을', 9100), ('손을 없을', 56591), ('없을 지경에까지', 69416), ('지경에까지 이르게', 94922), ('그러나 가족과', 14238), ('가족과 주민들의', 4097), ('주민들의 간절한', 93697), ('간절한 기도', 4698), ('기도 끝에', 15822), ('끝에 어린', 17760), ('어린 콜튼은', 68168), ('콜튼은 생사의', 103098), ('생사의 갈림길에서', 52494), ('갈림길에서 기적적으로', 4790), ('기적적으로 살아나게', 16562), ('살아나게 된다', 50966), ('이후 자신이', 82442), ('자신이 천국에', 86408), ('천국에 다녀왔다고', 98183), ('다녀왔다고 얘기하는', 21437), ('얘기하는 콜튼', 67707), ('콜튼 천국에서의', 103094), ('천국에서의 경험을', 98185), ('경험을 상세하게', 9606), ('상세하게 털어놓는', 51387), ('털어놓는 콜튼의', 104801), ('콜튼의 믿을', 103100), ('없는 이야기', 69199), ('이야기 때문에', 81498), ('때문에 세상이', 29726), ('세상이 들썩이기', 55181), ('들썩이기 시작하고', 28083), ('시작하고 갑작스런', 61540), ('갑작스런 소동에', 5898), ('소동에 조용했던', 55763), ('조용했던 마을은', 92753), ('마을은 혼란에', 33448), ('혼란에 빠지게', 114894), ('빠지게 된다', 49086), ('된다 천국을', 27243), ('천국을 경험', 98191), ('경험 했다는', 9575), ('했다는 콜튼으로', 113192), ('콜튼으로 인해', 103096), ('인해 아버지', 83351), ('아버지 토드와', 64190), ('토드와 그의', 105077), ('그의 가족은', 14931), ('도전을 하게', 25725), ('과연 콜튼이', 11506), ('콜튼이 경험한', 103102), ('경험한 천국은', 9672), ('천국은 진짜였을까', 98189), ('비보이들의', 48249), ('월드컵이라', 77573), ('댄스배틀', 24441), ('배틀', 44024), ('비보이의', 48253), ('영입하여', 72876), ('드림팀', 27962), ('모집한다', 38514), ('비보이들이', 48251), ('모이고', 38476), ('혹독한', 114856), ('거치면서', 7524), ('되어가는데', 27033), ('비보이팀들과', 48255), ('배틀을', 44028), ('넘기', 19337), ('상대는', 51172), ('다름아닌', 21743), ('어쌔신', 68433), ('최강이', 99365), ('비보이들의 월드컵이라', 48250), ('월드컵이라 불리는', 77574), ('불리는 세계', 47335), ('세계 최대의', 54449), ('최대의 댄스배틀', 99694), ('댄스배틀 배틀', 24442), ('배틀 오브', 44025), ('오브 이어', 74472), ('이어 미국', 81790), ('미국 비보이의', 40660), ('비보이의 명성을', 48254), ('명성을 되찾고', 37295), ('되찾고 싶은', 27175), ('싶은 힙합', 63248), ('힙합 프로듀서', 117454), ('프로듀서 단테', 109655), ('단테 우여곡절', 22442), ('끝에 젊은', 17763), ('젊은 시절', 90586), ('시절 동료인', 61655), ('동료인 제이슨', 26312), ('제이슨 코치로', 91616), ('코치로 영입하여', 102896), ('영입하여 드림팀', 72877), ('드림팀 모집한다', 27963), ('모집한다 미국', 38515), ('전역의 오디션을', 89750), ('통해 각양각색의', 105453), ('각양각색의 비보이들이', 4609), ('비보이들이 모이고', 48252), ('모이고 제이슨', 38477), ('제이슨 지휘', 91614), ('하에 혹독한', 111129), ('혹독한 훈련을', 114857), ('훈련을 거치면서', 116303), ('거치면서 점차', 7525), ('점차 하나의', 90715), ('하나의 팀이', 110736), ('팀이 되어가는데', 106718), ('되어가는데 전세계', 27034), ('전세계 20여', 89566), ('20여 국가의', 1566), ('국가의 최고', 13088), ('최고 비보이팀들과', 99378), ('비보이팀들과 배틀을', 48256), ('배틀을 펼쳐야', 44029), ('하는 그들', 110796), ('그들 앞에', 14009), ('가장 넘기', 3842), ('넘기 힘든', 19338), ('힘든 상대는', 117334), ('상대는 다름아닌', 51173), ('다름아닌 대한민국의', 21744), ('대한민국의 서울', 24261), ('서울 어쌔신', 52839), ('어쌔신 과연', 68434), ('과연 그들은', 11480), ('그들은 한국을', 14040), ('한국을 넘어', 111462), ('넘어 세계', 19420), ('세계 최강이', 54445), ('최강이 있을까', 99366), ('달튼이', 22725), ('잠에서', 87604), ('깨어나지', 17244), ('못하자', 39208), ('조쉬는', 92680), ('들어갔던', 28155), ('유체이탈을', 79133), ('영혼의', 72923), ('돌아왔지만', 26176), ('현상들이', 114175), ('막내인', 33933), ('갓난아기', 5905), ('주위를', 93979), ('맴도는', 36455), ('기운과', 16447), ('거실에서', 7335), ('연주되는', 72126), ('피아노', 110031), ('르네를', 32475), ('르네는', 32473), ('남편', 18797), ('조쉬에게서', 92682), ('맞닿아', 35472), ('수면위로', 56940), ('드러나는데', 27784), ('시간 아들', 60446), ('아들 달튼이', 63886), ('달튼이 잠에서', 22726), ('잠에서 깨어나지', 87605), ('깨어나지 못하자', 17245), ('못하자 아빠', 39209), ('아빠 조쉬는', 64258), ('조쉬는 과거', 92681), ('과거 자신의', 11385), ('자신의 속에', 86339), ('속에 들어갔던', 56312), ('들어갔던 경험을', 28156), ('경험을 살려', 9605), ('살려 유체이탈을', 50827), ('유체이탈을 시도해', 7 ...
# (90, 117459)

# %%
from sklearn.metrics.pairwise import cosine_similarity

genres_similarity = cosine_similarity(tfidf_matrix, tfidf_matrix)
print(genres_similarity)

similar_index = np.argsort(-genres_similarity)
print(similar_index)
# Out:
# [[1.         0.02273681 0.02634753 ... 0.00476316 0.00201344 0.00388201]
#  [0.02273681 1.         0.02783016 ... 0.00747722 0.00325252 0.00564527]
#  [0.02634753 0.02783016 1.         ... 0.00830409 0.00139802 0.00666348]
#  ...
#  [0.00476316 0.00747722 0.00830409 ... 1.         0.         0.00718531]
#  [0.00201344 0.00325252 0.00139802 ... 0.         1.         0.00542217]
#  [0.00388201 0.00564527 0.00666348 ... 0.00718531 0.00542217 1.        ]]
# [[ 0 19 22 ... 88 83 58]
#  [ 1 80 27 ... 85 70 58]
#  [ 2 29 25 ... 70 88 75]
#  ...
#  [87 55  9 ... 57 74 68]
#  [88 47 55 ... 57 77 74]
#  [89 60  3 ... 85 57 73]]

# %%
input_movie = input()
input_movie = input()
input_movie = input()

movie_index = movies[movies['code']==int(input_movie)].index.values
#print(movie_index)
similar_movies = similar_index[movie_index, 1:4]
#print(similar_movies)
# 인덱스로 사용하기 위해서는 1차원으로 변형해줘야하기 때문
similar_movies_index = similar_movies.reshape(-1)
#print(similar_movies_index)
#print(movies.iloc[similar_movies_index])

info = movies.iloc[similar_movies_index]
#print(info)
#print(info['code'])
code_info = list(np.array(info['code'].tolist()))
#print(code_info)

for i in code_info:
    CodetoTitle(i)
# Out:
# 투건스
# 마이 리틀 자이언트
# 어메이징 스파이더맨 2
